# %% [markdown]
# •	Fase 1: Extracción de Datos de API de MoviesDataset
#
# En esta fase, usaremos la API de MoviesDataset, que contiene una gran cantidad de información sobre películas, incluyendo detalles como títulos, géneros, años de lanzamiento y más. Vuestra tarea será hacer solicitudes a esta API y extraer información relevante sobre las películas. En concreto tendreis que sacar la siguiente información:
#
# o	Películas desde el 2010 hasta la actualidad.
#
# o	Películas que pertenezcan a los siguientes géneros: Drama, Comedy, Action.
#
# o	De cada una de las películas tendreis que sacar la siguiente información:
#
# 	Tipo (si es corto o película).
#
# 	Nombre de la película o el corto.
#
# 	Año de estreno de la película o corto.
#
# 	Mes de estreno de la película o corto.
#
# 	Id de la película.
#
# o	La documentación a la API la encontrarás aquí.
#
# o	NOTA: La información de la API deberá ser almacenada en una lista de tuplas. Cada tupla corresponderá a una película. Siguiendo el siguiente ejemplo:

# %%
# pendientes: 
    # Ver si hay sub-tipo de Movie que sea corto o long.
    # Usar params en la funcion de llamada en lugar de directamente usar la url que nos da la pagina
    # limpiar el código, comentar y dejar el código de testeo solo lo que sea necesario

# %%
#Complete code
import requests
import pandas as pd


# Define a function to call the API
def api_call(url, params):
    headers = {
        "x-rapidapi-key": "f600d33197mshe21c869c19877bbp16c957jsn8dea9e68b50b",
        "x-rapidapi-host": "moviesdatabase.p.rapidapi.com"
    }

    call = requests.get(url, headers=headers, params=params)
    print(f"The API call gave us a response of type: {call.status_code}")
    if call.status_code != 200:
        print(f"The reason for the failure is: {call.reason}")
        return None
    else:
        return call.json()

# Call the API

results_list = []

genre_list = ["Action", "Drama", "Comedy"]

for genre in genre_list:
    for i in range(1, 6):
        url_movies = f'https://moviesdatabase.p.rapidapi.com/titles?genre={genre}&startYear=2010&titleType=movie&page={i}&endYear=2024&limit=50'
        url_short = f'https://moviesdatabase.p.rapidapi.com/titles?genre={genre}&startYear=2010&titleType=short&page={i}&endYear=2024&limit=50'
        
        params_movies = None
        params_shorts = None
        
        # Call the API for movies and shorts
        response_dict_movies = api_call(url_movies, params_movies)
        response_dict_shorts = api_call(url_short, params_shorts)

        if response_dict_movies and "results" in response_dict_movies:
            for result in response_dict_movies["results"]:
                result["genre"] = genre
            results_list.extend(response_dict_movies["results"])
        if response_dict_shorts and "results" in response_dict_shorts:
            for result in response_dict_shorts["results"]:
                result["genre"] = genre
            results_list.extend(response_dict_shorts["results"])
        # if response_dict_movies and "results" in response_dict_movies:
        #     results_list.extend(response_dict_movies["results"])
        # if response_dict_shorts and "results" in response_dict_shorts:
        #     results_list.extend(response_dict_shorts["results"])
        
        print(f"\n ITERACION {genre} {i} \n")
        if response_dict_movies:
            print(f"\nThe answer for movies is type: {type(response_dict_movies)}, the length is: {len(response_dict_movies)} and the keys are: {response_dict_movies.keys()}\n")
            print(response_dict_movies)
        if response_dict_shorts:
            print(f"\nThe answer for shorts is type: {type(response_dict_shorts)}, the length is: {len(response_dict_shorts)} and the keys are: {response_dict_shorts.keys()}\n")
            print(response_dict_shorts)

print(f"\nThe type is: {type(results_list)}, the length is {len(results_list)}\n.")

movie_0 = results_list[0]
print(f"\nThe type is: {type(movie_0)}, the length is {len(movie_0)}.\n")
print(movie_0)

titleType = movie_0.get("titleType")
print(f"The titletype is {type(titleType)} whit {len(titleType)} elements and keys {titleType.keys()}")


full_movie_list = []

for movie in results_list:
    list = []
    list.append(movie["titleType"].get("text"))
    list.append(movie["titleText"].get("text"))
    list.append(movie["releaseYear"].get("year"))
    try:
        list.append(movie["releaseDate"].get("month"))
    except:
        list.append("none")
    list.append(movie["id"])
    list.append(movie["genre"])
   
    tupla = tuple(list)
    full_movie_list.append(tupla)

print(len(full_movie_list))
full_movie_list
# Out:
# The API call gave us a response of type: 200
# The API call gave us a response of type: 200
#
#  ITERACION Action 1
#
#
# The answer for movies is type: <class 'dict'>, the length is: 4 and the keys are: dict_keys(['page', 'next', 'entries', 'results'])
#
# ...

# %%
testing_list = [('Movie', '2 Fingers Honey 2', 2024, 2, 'tt31014713'), # to be used for testing the program with less results
 ('Movie', 'The Odd Room Mates', 2024, 3, 'tt30990201')]

# %%
# import libraries for data processing
# -----------------------------------------------------------------------
import pandas as pd

# Import libraries for web browser automation with Selenium
# -----------------------------------------------------------------------
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager # ChromeDriverManager manages the installation of the Chrome driver
from selenium.webdriver.common.keys import Keys # to simulate keyboard events in Selenium
from selenium.webdriver.support.ui import Select # to interact with <select> elements on web pages

# import libraries to pause execution
# -----------------------------------------------------------------------
from time import sleep  # Sleep is used to pause the execution of the program for a number of seconds

# settings
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None)  # Sets a Pandas option to display all columns of a DataFrame

# %%
#Open browser
driver = webdriver.Chrome()

#Variables with Selector to Use
url_cookies = "#__next > div > div > div.sc-jrcTuL.bPmWiM > div > button.icb-btn.sc-bcXHqe.sc-dkrFOg.sc-iBYQkv.dcvrLS.ddtuHe.dRCGjd"
url_search = "#suggestion-search"
url_lookup = "#suggestion-search-button > svg"
url_cast_access = "#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-c41b9732-0.NeSef > section > div:nth-child(5) > section > section > div.sc-66ec1b32-0.kbbKze > div > div:nth-child(2) > ul > li > a"
url_birth_year = "#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-c41b9732-0.NeSef > div > section > div > div.sc-978e9339-1.ihWZgK.ipc-page-grid__item.ipc-page-grid__item--span-2 > section:nth-child(18) > div.sc-f65f65be-0.bBlII > ul > li:nth-child(3) > div > ul > li.ipc-inline-list__item.test-class-react > a"
url_birth_year_exception = "#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-c41b9732-0.NeSef > section > div:nth-child(5) > section > section > div.sc-491663c0-4.yjUiO > div.sc-491663c0-6.lnlBxO > div.sc-491663c0-11.cvvyMK > section > aside > div > span:nth-child(2)"
url_awards = "#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-c41b9732-0.NeSef > section > div:nth-child(5) > section > section > div.sc-66ec1b32-0.kbbKze > div > div:nth-child(2) > ul > li:nth-child(2) > a"
url_actor_role = "#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-c41b9732-0.NeSef > section > div:nth-child(5) > section > section > div.sc-491663c0-3.bdjVSf > div > ul"
url_biography = "#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-c41b9732-0.NeSef > section > div:nth-child(5) > section > section > div.sc-66ec1b32-0.kbbKze > div > div:nth-child(2) > ul > li > a"


#full_movie_list = []

def open_browser(url, driver):
    #Navigate to website
    driver.get(url)
        
    #Maximize window
    driver.maximize_window()
    sleep(3)

def accept_cookies(url_cookies):

    #Accept cookies
    driver.find_element("css selector", url_cookies ).click()
    sleep(3)

def search_movie(url_search, url_lookup, url_cast_access, movie_list, relation_actor_movie):

    for movie_imbd in movie_list:
        print('Película:',movie_imbd)
        
        #Enter search
        driver.find_element("css selector", url_search).send_keys(movie_imbd[4])
    
        #Clivk lookup
        driver.find_element("css selector", url_lookup ).click()
        
        #Access cast
        driver.find_element("css selector", url_cast_access ).click()

        actor_list = retrieve_actor_data( url_birth_year, url_biography, url_actor_role, url_awards, movie_imbd[4], relation_actor_movie)
            
        #Add movie with actor list and info
        full_movie_list.append((movie_imbd, actor_list))
        print("Actors list:", actor_list)

       

def retrieve_actor_data(url_birth_year, url_biography, url_actor_role, url_awards, id_imdb, relation_actor_movie):
    
    #Retireve actors
    actor_list = []
   
    try: 
        for i in range(2, 4):
                        
            #Actor data
            #Name
            try:
                actor_name = driver.find_element("css selector", f"#fullcredits_content > table.cast_list > tbody > tr:nth-child({i}) > td:nth-child(2) > a" ).text
            except Exception as error:
                actor_name = None    
            print("Name:", actor_name)

            #Actor page
            try:
                driver.find_element("css selector", f"#fullcredits_content > table.cast_list > tbody > tr:nth-child({i}) > td:nth-child(2) > a" ).click()
            except Exception as error:
                print("Actor not found")
                
            #bith year
            try:
                actor_birth_year = driver.find_element("css selector", url_birth_year ).text
                actor_birth_year = int(actor_birth_year[-4:])
            except Exception as error:
                try:
                    actor_birth_year = driver.find_element("css selector", url_birth_year_exception ).text
                    actor_birth_year = int(actor_birth_year[-4:])
                except Exception as error:
                    actor_birth_year = None   
            print("Birth year:",actor_birth_year)
            
            #Biography
            try:
                driver.find_element("css selector", url_biography ).click()
            except Exception as error:
                print("Biography not found")
            
            #Known for
            known_for = []
            try:  
                for j in range(2,3):
                    known_for.append(driver.find_element("css selector", f"#mini_bio_0 > div > ul > div > div > a:nth-child({j})" ).text)
            except Exception as error:
                known_for.append(None)
            print("Know for:",known_for)

            #Exit biography
            driver.back()
            
            
            #Actor role
            actor_role = []
        
            try:
                actor_role_detail = driver.find_element("css selector", url_actor_role).text
                detail_with_comma = actor_role_detail.replace("\n", ", ")
                actor_role = detail_with_comma.split(",")
                
            except Exception as error:
                actor_role.append(None)
            print("Actor role:",actor_role)
            
            #Awards
            actor_awards = []

            try:
                
                driver.find_element("css selector", url_awards ).click()
                try:
                    
                    for h in range (3, 5):
                        detail = driver.find_element("css selector", f"#__next > main > div > section > div > section > div > div.sc-978e9339-1.ihWZgK.ipc-page-grid__item.ipc-page-grid__item--span-2 > section:nth-child({h}) > div.ipc-title.ipc-title--base.ipc-title--section-title.ipc-title--on-textPrimary").text
                        detail_whit_comma = detail.replace("\n", ", ")
                        actor_awards.append(detail_whit_comma )
                except Exception as error:
                    pass
                #Return to the actor´s page
                driver.back()
            except Exception as error:
                actor_awards.append(None)

            if actor_awards == []:
                actor_awards.append(None)
            print("Awards:",actor_awards)     

            #Add actor information list
            actor_list.append((actor_name, actor_birth_year, known_for, actor_role, actor_awards))

            relation_actor_movie.append([id_imdb, actor_name])

           
            driver.back()
    except Exception as error:
        pass

    return actor_list
   

# Main
relation_actor_movie = []
url = "https://www.imdb.com/"
open_browser(url, driver)
accept_cookies(url_cookies)
search_movie(url_search, url_lookup, url_cast_access, testing_list, relation_actor_movie)
print("Relation actor movie",relation_actor_movie)
# Out:
# Película: ('Movie', '2 Fingers Honey 2', 2024, 2, 'tt31014713')
# Name: Bujar Asqeriu
# Birth year: None
# Know for: ['Njeriu i mirë (1983)']
# Actor role: ['Reparto']
# Awards: [None]
# Name: Dashnor Diko
# Birth year: None
# Know for: ['Një Dado për Babin (2012)']
# Actor role: ['Reparto']
# Awards: [None]
# Actors list: [('Bujar Asqeriu', None, ['Njeriu i mirë (1983)'], ['Reparto'], [None]), ('Dashnor Diko', None, ['Një Dado për Babin (2012)'], ['Reparto'], [None])]
# Película: ('Movie', 'The Odd Room Mates', 2024, 3, 'tt30990201')
# Name: Mafe Ajoke
# Birth year: None
# Know for: ['Hotel Security (2023)']
# Actor role: ['Reparto']
# Awards: [None]
# Name: Chukz Onwuora
# Birth year: None
# Know for: [None]
# Actor role: ['Reparto']
# Awards: [None]
# Actors list: [('Mafe Ajoke', None, ['Hotel Security (2023)'], ['Reparto'], [None]), ('Chukz Onwuora', None, [None], ['Reparto'], [None])]
# ...

# %%
relation_actor_movie
# Out:
# [['Bujar Asqeriu', 'tt31014713'],
#  ['Dashnor Diko', 'tt31014713'],
#  ['Mafe Ajoke', 'tt30990201'],
#  ['Chukz Onwuora', 'tt30990201']]

# %%
#nombre de actor 
#fullcredits_content > table.cast_list > tbody > tr:nth-child(2) > td:nth-child(2) > a          ##hitpig
#fullcredits_content > table.cast_list > tbody > tr:nth-child(2) > td:nth-child(2) > a          ##multiverso

#año nacimiento
#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-c41b9732-0.NeSef > div > section > div > div.sc-978e9339-1.ihWZgK.ipc-page-grid__item.ipc-page-grid__item--span-2 > section:nth-child(18) > div.sc-f65f65be-0.bBlII > ul > li:nth-child(3) > div > ul > li.ipc-inline-list__item.test-class-react > a
#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-c41b9732-0.NeSef > div > section > div > div.sc-978e9339-1.ihWZgK.ipc-page-grid__item.ipc-page-grid__item--span-2 > section:nth-child(23) > div.sc-f65f65be-0.bBlII > ul > li:nth-child(4) > div > ul > li.ipc-inline-list__item.test-class-react > a"
#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-c41b9732-0.NeSef > div > section > div > div.sc-978e9339-1.ihWZgK.ipc-page-grid__item.ipc-page-grid__item--span-2 > section:nth-child(18) > div.sc-f65f65be-0.bBlII > ul > li:nth-child(3) > div > ul > li.ipc-inline-list__item.test-class-react > a
#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-c41b9732-0.NeSef > section > div:nth-child(5) > section > section > div.sc-491663c0-4.yjUiO > div.sc-491663c0-6.lnlBxO > div.sc-491663c0-11.cvvyMK > section > aside > div > span:nth-child(2)

#conocido por
#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-c41b9732-0.NeSef > section > div:nth-child(5) > section > section > div.sc-491663c0-4.yjUiO > div.sc-491663c0-6.lnlBxO > div.sc-491663c0-10.rbXFE > section > div > div
#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-c41b9732-0.NeSef > section > div:nth-child(5) > section > section > div.sc-491663c0-4.yjUiO > div.sc-491663c0-6.lnlBxO > div.sc-491663c0-10.rbXFE > section > div > div > div > div"
#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-c41b9732-0.NeSef > section > div:nth-child(5) > section > section > div.sc-491663c0-4.yjUiO > div.sc-491663c0-6.lnlBxO > div.sc-491663c0-10.rbXFE > section > div > div > div > div
#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-c41b9732-0.NeSef > section > div:nth-child(5) > section > section > div.sc-491663c0-4.yjUiO > div.sc-491663c0-6.lnlBxO > div.sc-491663c0-10.rbXFE > section > div > div > div > div
#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-c41b9732-0.NeSef > section > div:nth-child(5) > section > section > div.sc-491663c0-4.gEsAEH > div.sc-491663c0-6.eQRCDK > div.sc-491663c0-10.emoxHI > section > div > div > div > div
#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-c41b9732-0.NeSef > section > div:nth-child(5) > section > section > div.sc-491663c0-4.fVGakt > div > div.sc-491663c0-10.RRTJr > section > div > div > div > div > a
#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-c41b9732-0.NeSef > section > div:nth-child(5) > section > section > div.sc-491663c0-4.yjUiO > div.sc-491663c0-6.lnlBxO > div.sc-491663c0-10.rbXFE > section > div > div > div > div
#mini_bio_0 > div > ul > div > div > a:nth-child(1)

#qué hace
#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-c41b9732-0.NeSef > div > section > div > div.sc-978e9339-1.ihWZgK.ipc-page-grid__item.ipc-page-grid__item--span-2 > div.celwidget > section:nth-child(2) > div.ipc-title.ipc-title--base.ipc-title--title.ipc-title--on-textPrimary.sc-817d5c6e-5.jRSBVq.filmo-section-actor > hgroup > h3
#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-c41b9732-0.NeSef > section > div:nth-child(5) > section > section > div.sc-491663c0-3.bdjVSf > div > ul

#premios
#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-c41b9732-0.NeSef > section > div:nth-child(5) > section > section > div.sc-66ec1b32-0.kbbKze > div > div:nth-child(2) > ul > li:nth-child(2) > a
#__next > main > div > section > div > section > div > div.sc-978e9339-1.ihWZgK.ipc-page-grid__item.ipc-page-grid__item--span-2 > section:nth-child(3)
#ev0001969
#ev0000453
#__next > main > div > section > div > section > div > div.sc-978e9339-1.ihWZgK.ipc-page-grid__item.ipc-page-grid__item--span-2 > section:nth-child(3) > div.ipc-title.ipc-title--base.ipc-title--section-title.ipc-title--on-textPrimary

# %%
#cookies
#__next > div > div > div.sc-jrcTuL.bPmWiM > div > button.icb-btn.sc-bcXHqe.sc-dkrFOg.sc-iBYQkv.dcvrLS.ddtuHe.dRCGjd
#buscar
#suggestion-search
#lupa
#suggestion-search-button > svg
#coincidencias exactas
#__next > main > div.ipc-page-content-container.ipc-page-content-container--full.sc-e51f9d6d-0.Fmvqg > div.ipc-page-content-container.ipc-page-content-container--center > section > div > div.ipc-page-grid__item.ipc-page-grid__item--span-2 > section:nth-child(4) > div.ipc-title.ipc-title--base.ipc-title--section-title.ipc-title--on-textPrimary.sc-a9505ad5-1.dPVhUG > div > div > a > span
#__next > main > div.ipc-page-content-container.ipc-page-content-container--full.sc-e51f9d6d-0.Fmvqg > div.ipc-page-content-container.ipc-page-content-container--center > section > div > div.ipc-page-grid__item.ipc-page-grid__item--span-2 > section:nth-child(4) > div.ipc-title.ipc-title--base.ipc-title--section-title.ipc-title--on-textPrimary.sc-e8e4ce7-1.ksYNgL > div > div > a > span
#url_coincidencias_exactas = "#__next > main > div.ipc-page-content-container.ipc-page-content-container--full.sc-e51f9d6d-0.Fmvqg > div.ipc-page-content-container.ipc-page-content-container--center > section > div > div.ipc-page-grid__item.ipc-page-grid__item--span-2 > section:nth-child(4) > div.ipc-title.ipc-title--base.ipc-title--section-title.ipc-title--on-textPrimary.sc-a9505ad5-1.dPVhUG > div > div > a > span"
#url_coincidencias_exactas_exception = "#__next > main > div.ipc-page-content-container.ipc-page-content-container--full.sc-e51f9d6d-0.Fmvqg > div.ipc-page-content-container.ipc-page-content-container--center > section > div > div.ipc-page-grid__item.ipc-page-grid__item--span-2 > section:nth-child(4) > div.ipc-title.ipc-title--base.ipc-title--section-title.ipc-title--on-textPrimary.sc-e8e4ce7-1.ksYNgL > div > div > a > span"

#entrada pelicula
#__next > main > div.ipc-page-content-container.ipc-page-content-container--full.sc-e51f9d6d-0.Fmvqg > div.ipc-page-content-container.ipc-page-content-container--center > section > div > div.ipc-page-grid__item.ipc-page-grid__item--span-2 > section.ipc-page-section.ipc-page-section--base.sc-a9505ad5-0.czWaTH > div.sc-a9505ad5-2.ZcXyE > ul > li:nth-child(1) > div.ipc-metadata-list-summary-item__c > div > a
#reparto
#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-c41b9732-0.NeSef > div > section > div > div.sc-978e9339-1.ihWZgK.ipc-page-grid__item.ipc-page-grid__item--span-2 > section.ipc-page-section.ipc-page-section--base.sc-bfec09a1-0.jgUBLM.title-cast.title-cast--movie.celwidget > div.ipc-title.ipc-title--base.ipc-title--section-title.ipc-title--on-textPrimary > div > a > h3 > span:nth-child(1)
#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-c41b9732-0.NeSef > div > section > div > div.sc-978e9339-1.ihWZgK.ipc-page-grid__item.ipc-page-grid__item--span-2 > section.ipc-page-section.ipc-page-section--base.sc-bfec09a1-0.jgUBLM.title-cast.title-cast--movie.celwidget > div.ipc-title.ipc-title--base.ipc-title--section-title.ipc-title--on-textPrimary > div > a > h3 > svg
#//*[@id="__next"]/main/div/section[1]/div/section/div/div[1]/section[2]/div[1]/div/a/h3/span[1]
#url_entrar_pelicula = "#__next > main > div.ipc-page-content-container.ipc-page-content-container--full.sc-e51f9d6d-0.Fmvqg > div.ipc-page-content-container.ipc-page-content-container--center > section > div > div.ipc-page-grid__item.ipc-page-grid__item--span-2 > section.ipc-page-section.ipc-page-section--base.sc-a9505ad5-0.czWaTH > div.sc-a9505ad5-2.ZcXyE > ul > li:nth-child(1) > div.ipc-metadata-list-summary-item__c > div > a"
#url_entrar_pelicula_exception = "#__next > main > div.ipc-page-content-container.ipc-page-content-container--full.sc-e51f9d6d-0.Fmvqg > div.ipc-page-content-container.ipc-page-content-container--center > section > div > div.ipc-page-grid__item.ipc-page-grid__item--span-2 > section.ipc-page-section.ipc-page-section--base.sc-e8e4ce7-0.bEmpTm > div.sc-e8e4ce7-2.iXsuvN > ul > li > div.ipc-metadata-list-summary-item__c > div > a"
#tabla reparto
#fullcredits_content > table.cast_list > tbody > tr:nth-child(2) > td:nth-child(2) > a
#fullcredits_content > table.cast_list

#Entrar reparto
#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-c41b9732-0.NeSef > section > div:nth-child(5) > section > section > div.sc-491663c0-4.yjUiO > div.sc-491663c0-6.lnlBxO > div.sc-491663c0-10.rbXFE > section > div.sc-1f50b7c-3.ZYFjc > div > ul > li.ipc-metadata-list__item.ipc-metadata-list-item--link > a.ipc-metadata-list-item__icon-link > svg
#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-c41b9732-0.NeSef > section > div:nth-child(5) > section > section > div.sc-491663c0-4.yjUiO > div.sc-491663c0-6.lnlBxO > div.sc-491663c0-10.rbXFE > section > div.sc-1f50b7c-3.ZYFjc > div > ul > li.ipc-metadata-list__item.ipc-metadata-list-item--link > a.ipc-metadata-list-item__icon-link > svg
#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-c41b9732-0.NeSef > section > div:nth-child(5) > section > section > div.sc-491663c0-4.yjUiO > div.sc-491663c0-6.lnlBxO > div.sc-491663c0-10.rbXFE > section > div.sc-1f50b7c-3.ZYFjc > div > ul > li.ipc-metadata-list__item.ipc-metadata-list-item--link > a.ipc-metadata-list-item__label.ipc-metadata-list-item__label--link
#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-c41b9732-0.NeSef > section > div:nth-child(5) > section > section > div.sc-491663c0-4.gEsAEH > div.sc-491663c0-6.eQRCDK > div.sc-491663c0-10.emoxHI > section > div.sc-1f50b7c-3.ZYFjc > div > ul > li.ipc-metadata-list__item.ipc-metadata-list-item--link > a.ipc-metadata-list-item__label.ipc-metadata-list-item__label--link
#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-c41b9732-0.NeSef > section > div:nth-child(5) > section > section > div.sc-491663c0-4.gEsAEH > div.sc-491663c0-6.eQRCDK > div.sc-491663c0-10.emoxHI > section > div.sc-1f50b7c-3.ZYFjc > div > ul > li.ipc-metadata-list__item.ipc-metadata-list-item--link > a.ipc-metadata-list-item__label.ipc-metadata-list-item__label--link
#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-c41b9732-0.NeSef > section > div:nth-child(5) > section > section > div.sc-491663c0-4.gEsAEH > div.sc-491663c0-6.eQRCDK > div.sc-491663c0-10.emoxHI > section > div.sc-1f50b7c-3.ZYFjc > div > ul > li.ipc-metadata-list__item.ipc-metadata-list-item--link > a.ipc-metadata-list-item__icon-link
#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-c41b9732-0.NeSef > section > div:nth-child(5) > section > section > div.sc-66ec1b32-0.kbbKze > div > div:nth-child(2) > ul > li > a
#url_entrar_reparto_if = "#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-c41b9732-0.NeSef > section > div:nth-child(5) > section > section > div.sc-491663c0-4.gEsAEH > div.sc-491663c0-6.eQRCDK > div.sc-491663c0-10.emoxHI > section > div.sc-1f50b7c-3.ZYFjc > div > ul > li.ipc-metadata-list__item.ipc-metadata-list-item--link > a.ipc-metadata-list-item__label.ipc-metadata-list-item__label--link"
#url_entrar_reparto_exception = "#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-c41b9732-0.NeSef > section > div:nth-child(5) > section > section > div.sc-491663c0-4.yjUiO > div.sc-491663c0-6.lnlBxO > div.sc-491663c0-10.rbXFE > section > div.sc-1f50b7c-3.ZYFjc > div > ul > li.ipc-metadata-list__item.ipc-metadata-list-item--link > a.ipc-metadata-list-item__icon-link > svg"
#url_recuperar_actores = f"#fullcredits_content > table.cast_list > tbody > tr:nth-child({i}) > td:nth-child(2) > a"


#Detalle actor
#fullcredits_content > table.cast_list > tbody > tr:nth-child(2) > td:nth-child(2) > a

# %%
type(lista_general)
# Out:
# list

# %%
# try:
    #     if pelicula_imbd[1] == "Staycation" or pelicula_imbd[1] == "Broken Glass":  #url diferente a las demas
    #         driver.find_element("css selector", url_entrar_reparto_if ).click()
    #     else:
    #         driver.find_element("css selector", url_entrar_reparto ).click()
    # except Exception as error:
    #     sleep(3)
    #     driver.find_element("css selector", url_entrar_reparto_exception ).click()

  # Contar el número de películas por las que es conocido
            #peliculas_conocido = driver.find_elements("css selector", url_conocido_por )
            #peliculas_conocido
            #numero_peliculas_conocido = len(peliculas_conocido)
            #numero_peliculas_conocido

# esta aqui para forzar que busque esta pelicula para probar que recuperamos todos los datos
    #pelicula_imbd = ('Movie', 'Harold and the Purple Crayon', 2024, 8, 'tt0185431')

# %%
# #qué hace  
#         que_hace_actor = []
#         try:
#             que_hace_actor.append(driver.find_element("css selector", url_que_hace_actor ).text)
#         except Exception as error:
#             que_hace_actor.append(None)
#         print("Qué hace:",que_hace_actor)

# %%
# Debereis solo tener en cuenta los 10 primeros actores de cada película o corto (en caso de que los haya)
# La información que deberás extraer es:
# o	Nombre.
# o	Año nacimiento.
# o	¿Por qué es conocido?
# o	¿Qué hace?
# o	Premios.
# o	NOTA: La información de la API deberá ser almacenada en una lista de tuplas. 
# Cada tupla corresponderá a una película. Siguiendo el siguiente ejemplo:

# [("Adam Sadler", 1966, ["El aguador", "Little Nicky", "Un papá genial", 
# "El chico ideal" ], ["Reparto", "Producción", "Guion"] , ["American Comedy Awards, USA", "Annie Awards"],   ),
