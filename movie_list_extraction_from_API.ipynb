# %%
import requests
import pandas as pd

# %%
# Key Bea = 30f6c00168msh1b42af1260e2970p1cb797jsn775f4f1bf53e
# Key Bea2 = 7da7d1d9f2mshd70f16dedff8827p11e4cejsnc105329a0d9c
# Key Ceci = dab5a0167dmsh4ab1543f0fd8e0ap1d9b21jsnd66b36d85213
# Key Carla = f600d33197mshe21c869c19877bbp16c957jsn8dea9e68b50b

# API call
def api_call(url):
    headers = {
        "x-rapidapi-key": "30f6c00168msh1b42af1260e2970p1cb797jsn775f4f1bf53e", 
        "x-rapidapi-host": "moviesdatabase.p.rapidapi.com"
    }

    call = requests.get(url, headers=headers)
    print(f"The API call gave us a response of type: {call.status_code}")
    if call.status_code != 200:
        print(f"The reason for the failure is: {call.reason}")
        return None
    else:
        return call.json()

# List of movies by genre
def movies_by_genre(genre_list):
    movies_list = []

    for genre in genre_list:
        for i in range(31,61): # Iteration range equivalent to pages. You can change this.
            url_movies = f'https://moviesdatabase.p.rapidapi.com/titles?genre={genre}&startYear=2010&titleType=movie&page={i}&endYear=2024&limit=50'
            response_dict_movies = api_call(url_movies)

            if response_dict_movies and "results" in response_dict_movies:
                for result in response_dict_movies["results"]:
                    result["genre"] = genre
                movies_list.extend(response_dict_movies["results"])

            print(f"\n ITERACION {genre} {i} \n")
            if response_dict_movies:
                print(f"\nThe answer for movies is type: {type(response_dict_movies)}, the length is: {len(response_dict_movies)} and the keys are: {response_dict_movies.keys()}\n")
                print(response_dict_movies)

    return movies_list

# List of shorts by genre
def shorts_by_genre(genre_list):
    shorts_list = []

    for genre in genre_list:
        for i in range(31,61): # Rango de iteración equivalente a las páginas
            url_short = f'https://moviesdatabase.p.rapidapi.com/titles?genre={genre}&startYear=2010&titleType=short&page={i}&endYear=2024&limit=50'
            response_dict_shorts = api_call(url_short)
            if response_dict_shorts and "results" in response_dict_shorts:
                for result in response_dict_shorts["results"]:
                    result["genre"] = genre
                shorts_list.extend(response_dict_shorts["results"])

            print(f"\n ITERACION {genre} {i} \n")
            if response_dict_shorts:
                print(f"\nThe answer for shorts is type: {type(response_dict_shorts)}, the length is: {len(response_dict_shorts)} and the keys are: {response_dict_shorts.keys()}\n")
                print(response_dict_shorts)

    return shorts_list

# Creation of tuple with data
def process_results(results_list):
    full_list = []
    for item in results_list:
        item_data = []
        item_data.append(item["titleType"].get("text"))
        item_data.append(item["titleText"].get("text"))
        item_data.append(item["releaseYear"].get("year"))
        try:
            item_data.append(item["releaseDate"].get("month"))
        except:
            item_data.append("none")
        item_data.append(item["id"])
        item_data.append(item["genre"])
        
        full_list.append(tuple(item_data))
    return full_list

# Join movies and shorts in one list
def combine_results(genre_list):
    movies_list = movies_by_genre(genre_list)
    shorts_list = shorts_by_genre(genre_list)
    
    combined_list = movies_list + shorts_list
    processed_list = process_results(combined_list)
    
    return processed_list

# Call to main function
genre_list = ["Action"] # Genres: "Action", "Drama", "Comedy"
combined_results = combine_results(genre_list)

# Create DataFrame
list_headers = ["type", "name", "release_year", "release_month", "id_imdb", "genre"]
df_full_movie_list = pd.DataFrame(combined_results, columns=list_headers)

# Set 'id_imdb' as index
df_full_movie_list.set_index('id_imdb', inplace=True)

# Show DataFrame
df_full_movie_list
# Out:
# The API call gave us a response of type: 200
#
#  ITERACION Action 31
#
#
# The answer for movies is type: <class 'dict'>, the length is: 4 and the keys are: dict_keys(['page', 'next', 'entries', 'results'])
#
# {'page': '31', 'next': '/titles?titleType=movie&genre=Action&page=32&limit=50&startYear=2010&endYear=2024', 'entries': 50, 'results': [{'_id': '61e5ac3ad8f3c0931e4bcb0d', 'id': 'tt15708990', 'primaryImage': None, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, 'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}], 'canHaveEpisodes': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Black Widows', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Black Widows', '__typename': 'TitleText'}, 'releaseYear': {'year': 2022, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 15, 'month': 12, 'year': 2022, '__typename': 'ReleaseDate'}, 'genre': 'Action'}, {'_id': '61e5acdbef99b1c5434beeb3', 'id': 'tt1630029', 'primaryImage': {'id': 'rm92486145', 'width': 900, 'height': 1289, 'url': 'https://m.media-amazon.com/images/M/MV5BYjhiNjBlODctY2ZiOC00YjVlLWFlNzAtNTVhNzM1YjI1NzMxXkEyXkFqcGdeQXVyMjQxNTE1MDA@._V1_.jpg', 'caption': {'plainText': "Zoe Saldana, Sam Worthington, Bailey Bass, and Jamie Flatters in Avatar - La via dell'acqua (2022)", '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, 'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}], 'canHaveEpisodes': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Avatar: The Way of Water', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Avatar: The Way of Water', '__typename': 'TitleText'}, 'releaseYear': {'year': 2022, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 14, 'month': 12, 'year': 2022, '__typename': 'ReleaseDate'}, 'genre': 'Action'}, {'_id': '61e5ad0fcffb8f2faa4bf9dd', 'id': 'tt1649418', 'primaryImage': {'id': 'rm2121338881', 'width': 1500, 'height': 2222, 'url': 'https://m.media-amazon.com/images/M/MV5BOWY4MmFiY2QtMzE1YS00NTg1LWIwOTQtYTI4ZGUzNWIxNTVmXkEyXkFqcGdeQXVyODk4OTc3MTY@._V1_.jpg', 'caption': {'plainText': 'Chris Evans and Ryan Gosling in The Gray Man (2022)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, 'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}], 'canHaveEpisodes': False, '__typename': 'TitleType'}, 'titleText': {'text': 'The Gray Man', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'The Gray Man', '__typename': 'TitleText'}, 'releaseYear': {'year': 2022, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 22, 'month': 7, 'year': 2022, '__typename': 'ReleaseDate'}, 'genre': 'Action'}, {'_id': '61e5ad1de1a8ddbd964c0007', 'id': 'tt1655444', 'primaryImage': {'id': 'rm2166163969', 'width': 453, 'height': 650, 'url': 'https://m.media-amazon.com/images/M/MV5BYjNiMjFmZGQtMWJlMi00Y2FhLTljZDQtOGVlNjY5OTdiZWI1XkEyXkFqcGdeQXVyNDA1NDA2NTk@._V1_.jpg', 'caption': {'plainText': 'Ron Perlman, Tim Roth, Paz Vega, and José María Yazpik in There Are No Saints (2022)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, 'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}], 'canHaveEpisodes': False, '__typename': 'TitleType'}, 'titleText': {'text': 'There Are No Saints', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'There Are No Saints', '__typename': 'TitleText'}, 'releaseYear': {'year': 2022, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 27, 'month': 5, 'year': 2022, '__typename': 'ReleaseDate'}, 'genre': 'Action'}, {'_id': '61e5ae10ef99b1c5434c3709', 'id': 'tt1745960', 'primaryImage': {'id': 'rm3294367489', 'width': 2531, 'height': 3750, 'url': 'https://m.media-amazon.com/images/M/MV5BZWYzOGEwNTgtNWU3NS00ZTQ0LWJkODUtMmVhMjIwMjA1ZmQwXkEyXkFqcGdeQXVyMjkwOTAyMDU@._V1_.jpg', 'caption': {'plainText': 'Top Gun: Maverick (2022)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text ...
# The API call gave us a response of type: 200
#
#  ITERACION Action 32
#
#
# The answer for movies is type: <class 'dict'>, the length is: 4 and the keys are: dict_keys(['page', 'next', 'entries', 'results'])
#
# {'page': '32', 'next': '/titles?titleType=movie&genre=Action&page=33&limit=50&startYear=2010&endYear=2024', 'entries': 50, 'results': [{'_id': '61e5c9ad909c2ca78152cfcd', 'id': 'tt16425304', 'primaryImage': {'id': 'rm690808321', 'width': 720, 'height': 1280, 'url': 'https://m.media-amazon.com/images/M/MV5BNTkyZTNiZjMtOGVlNS00YWQ3LTk2ZDktNTA4N2JiYTQxM2ZkXkEyXkFqcGdeQXVyMTQ1MzUwNzky._V1_.jpg', 'caption': {'plainText': 'Devil Doom Karate (2022)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, 'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}], 'canHaveEpisodes': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Devil Doom Karate', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Devil Doom Karate', '__typename': 'TitleText'}, 'releaseYear': {'year': 2022, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 25, 'month': 3, 'year': 2022, '__typename': 'ReleaseDate'}, 'genre': 'Action'}, {'_id': '61e5ca42ef99b1c54352f237', 'id': 'tt8312728', 'primaryImage': {'id': 'rm2476277249', 'width': 1536, 'height': 2048, 'url': 'https://m.media-amazon.com/images/M/MV5BZTBiZTg1NDktNDEyNi00YWU1LWExYmQtODA5OTY4MDM2Yzk1XkEyXkFqcGdeQXVyOTg1MDkzOTM@._V1_.jpg', 'caption': {'plainText': 'Emmanuel Buriez in Arion Among the Waves (2022)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, 'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}], 'canHaveEpisodes': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Arion Among the Waves', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Arion Among the Waves', '__typename': 'TitleText'}, 'releaseYear': {'year': 2022, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 14, 'month': 12, 'year': 2022, '__typename': 'ReleaseDate'}, 'genre': 'Action'}, {'_id': '61e5ca50ef99b1c54352f5cd', 'id': 'tt15816274', 'primaryImage': {'id': 'rm1432480513', 'width': 1131, 'height': 1600, 'url': 'https://m.media-amazon.com/images/M/MV5BN2YxYmExNDItNWYzNC00MzI4LWI5NjktZjZhNDFhOGVmNWI0XkEyXkFqcGdeQXVyNjM2MDY2MTA@._V1_.jpg', 'caption': {'plainText': 'Secret of the Shroud (2022)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, 'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}], 'canHaveEpisodes': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Secret of the Shroud', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Secret of the Shroud', '__typename': 'TitleText'}, 'releaseYear': {'year': 2022, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 28, 'month': 1, 'year': 2022, '__typename': 'ReleaseDate'}, 'genre': 'Action'}, {'_id': '61e5ca64e1a8ddbd9652fe67', 'id': 'tt7089544', 'primaryImage': {'id': 'rm241704705', 'width': 1211, 'height': 1754, 'url': 'https://m.media-amazon.com/images/M/MV5BOWQyYTRjNGQtN2ZjYS00NWQ4LWJiYmQtNGUzYjdkMWNmODczXkEyXkFqcGdeQXVyMjMxNjQ4MDI@._V1_.jpg', 'caption': {'plainText': 'Thirteen Cars (2022)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, 'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}], 'canHaveEpisodes': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Thirteen Cars', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Thirteen Cars', '__typename': 'TitleText'}, 'releaseYear': {'year': 2022, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': None, 'month': None, 'year': 2022, '__typename': 'ReleaseDate'}, 'genre': 'Action'}, {'_id': '61e5ca71e1a8ddbd96530177', 'id': 'tt16117360', 'primaryImage': {'id': 'rm2454055169', 'width': 1080, 'height': 1441, 'url': 'https://m.media-amazon.com/images/M/MV5BMTM2MTUxYjYtM2Y1My00YjYzLWE5MDUtOTY5NWYzYmJhOT ...
# The API call gave us a response of type: 200
#
#  ITERACION Action 33
#
#
# The answer for movies is type: <class 'dict'>, the length is: 4 and the keys are: dict_keys(['page', 'next', 'entries', 'results'])
#
# {'page': '33', 'next': '/titles?titleType=movie&genre=Action&page=34&limit=50&startYear=2010&endYear=2024', 'entries': 50, 'results': [{'_id': '61e5d11478c012aa34548c67', 'id': 'tt7023644', 'primaryImage': {'id': 'rm2570259201', 'width': 1275, 'height': 1411, 'url': 'https://m.media-amazon.com/images/M/MV5BMWU5MjE5MTktOWQwYS00NjFmLWE3NjEtYzJmZDQwMThlZDdkXkEyXkFqcGdeQXVyMTEzNzg0Mjkx._V1_.jpg', 'caption': {'plainText': 'G.V. Prakash Kumar and Mahima Nambiar in Ayngaran (2022)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, 'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}], 'canHaveEpisodes': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Ayngaran', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Ayngaran', '__typename': 'TitleText'}, 'releaseYear': {'year': 2022, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 12, 'month': 5, 'year': 2022, '__typename': 'ReleaseDate'}, 'genre': 'Action'}, {'_id': '61e5d1758a5a6a599f54abb1', 'id': 'tt8907974', 'primaryImage': {'id': 'rm567992321', 'width': 1412, 'height': 2048, 'url': 'https://m.media-amazon.com/images/M/MV5BMDZkMmEzMjctN2UzZC00YjJkLWIyYTgtMDdiZGZkNTMwNGI0XkEyXkFqcGdeQXVyMTEzMTI1Mjk3._V1_.jpg', 'caption': {'plainText': 'Looop Lapeta (2022)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, 'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}], 'canHaveEpisodes': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Looop Lapeta', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Looop Lapeta', '__typename': 'TitleText'}, 'releaseYear': {'year': 2022, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 4, 'month': 2, 'year': 2022, '__typename': 'ReleaseDate'}, 'genre': 'Action'}, {'_id': '61e5d1da8a5a6a599f54c459', 'id': 'tt15745084', 'primaryImage': {'id': 'rm2679444993', 'width': 491, 'height': 654, 'url': 'https://m.media-amazon.com/images/M/MV5BMDUwNDNjZTQtZTk5ZS00OGRlLTk1MzItN2E0ZTQ1MGQzNzI5XkEyXkFqcGdeQXVyMTAzOTA4NjM@._V1_.jpg', 'caption': {'plainText': 'Grace Van Dien, Pauline Dyer, and Jocelyn Hudon in V for Vengeance (2022)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, 'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}], 'canHaveEpisodes': False, '__typename': 'TitleType'}, 'titleText': {'text': 'V for Vengeance', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'V for Vengeance', '__typename': 'TitleText'}, 'releaseYear': {'year': 2022, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 7, 'month': 6, 'year': 2022, '__typename': 'ReleaseDate'}, 'genre': 'Action'}, {'_id': '61e5d20de1a8ddbd9654cdf1', 'id': 'tt16220010', 'primaryImage': {'id': 'rm1335749633', 'width': 1080, 'height': 1350, 'url': 'https://m.media-amazon.com/images/M/MV5BNTk0MzY0NGUtZTQ3YS00MGMxLWFkZDgtY2Y5YmE2MDM5ZjFhXkEyXkFqcGdeQXVyMTM1NjAwNTI2._V1_.jpg', 'caption': {'plainText': 'Warning 2 (2022)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, 'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}], 'canHaveEpisodes': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Warning 2', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Warning 2', '__typename': 'TitleText'}, 'releaseYear': {'year': 2022, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 22, 'month': 7, 'year': 2022, '__typename': 'ReleaseDate'}, 'genre': 'Action'}, {'_id': '61e5d214a66e59642354caed', 'id': 'tt16044668', 'primaryImage': {'id': 'rm2286151681', 'width': 2000, 'height': 3000, 'url': 'https://m.media-amazon.com/images/M/MV5BOTdlZjlmNjItMzE3MS00MzBiLThiZjAtODNhNjIyMjkwMjJkXkEyXkFqcGdeQX ...
# The API call gave us a response of type: 200
#
#  ITERACION Action 34
#
#
# The answer for movies is type: <class 'dict'>, the length is: 4 and the keys are: dict_keys(['page', 'next', 'entries', 'results'])
#
# {'page': '34', 'next': '/titles?titleType=movie&genre=Action&page=35&limit=50&startYear=2010&endYear=2024', 'entries': 50, 'results': [{'_id': '61e5da00b597b91eb956be11', 'id': 'tt8883486', 'primaryImage': {'id': 'rm3059157249', 'width': 999, 'height': 1499, 'url': 'https://m.media-amazon.com/images/M/MV5BNmEyNjNkYTUtNTJkYi00MjRlLWIzZTgtNmIyNzVhODA5MWJlXkEyXkFqcGdeQXVyMTA3MDk2NDg2._V1_.jpg', 'caption': {'plainText': 'Medieval (2022)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, 'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}], 'canHaveEpisodes': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Medieval', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Medieval', '__typename': 'TitleText'}, 'releaseYear': {'year': 2022, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 8, 'month': 11, 'year': 2022, '__typename': 'ReleaseDate'}, 'genre': 'Action'}, {'_id': '61e5da3a971a4a15d656d08d', 'id': 'tt15837546', 'primaryImage': {'id': 'rm4224714241', 'width': 3580, 'height': 5033, 'url': 'https://m.media-amazon.com/images/M/MV5BMGJhYjFkYTctMmYyZi00ODQxLWJkY2EtNmUyZWU0MGQ0NzQzXkEyXkFqcGdeQXVyNTIzMDgzNjY@._V1_.jpg', 'caption': {'plainText': 'Riot for the dove (2022)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, 'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}], 'canHaveEpisodes': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Riot for the dove', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Riot for the dove', '__typename': 'TitleText'}, 'releaseYear': {'year': 2022, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 15, 'month': 1, 'year': 2022, '__typename': 'ReleaseDate'}, 'genre': 'Action'}, {'_id': '61e5da5f8a5a6a599f56dbb1', 'id': 'tt16604920', 'primaryImage': {'id': 'rm3425692929', 'width': 1587, 'height': 2245, 'url': 'https://m.media-amazon.com/images/M/MV5BNWJjZmJiZDMtY2I0YS00YzBmLThiMjItNWIzZjhhZjAyOTcyXkEyXkFqcGdeQXVyNDcwOTM2MDk@._V1_.jpg', 'caption': {'plainText': "Sergio Rojas, Pipe Gonzalez, Katty Vega, Ernesto Cordova, Maria Paola D'Orlemont, Jorge Rodriguez, Ricardo Palacios, Juan Francisco Selles, and Adrian Mora in Víboras de Oropel (2022)", '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, 'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}], 'canHaveEpisodes': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Víboras de Oropel', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Víboras de Oropel', '__typename': 'TitleText'}, 'releaseYear': {'year': 2022, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': None, 'month': None, 'year': 2022, '__typename': 'ReleaseDate'}, 'genre': 'Action'}, {'_id': '61e5da7eef99b1c54356dc33', 'id': 'tt9009056', 'primaryImage': {'id': 'rm247168256', 'width': 2480, 'height': 3508, 'url': 'https://m.media-amazon.com/images/M/MV5BODZkMTRhYjctMzA1ZC00NTcxLWI3MmEtZTQzMGQ3ODBiNmU1XkEyXkFqcGdeQXVyOTI1ODMxNTc@._V1_.jpg', 'caption': {'plainText': 'Yusof B. Mohd Kassim, Subash Sundaramoothy, Van Jhoov, Baf Sjamsuddin, Bobby Alatas, and Johnny Silmon in Ksatria (2022)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, 'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}], 'canHaveEpisodes': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Ksatria', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Ksatria', '__typename': 'TitleText'}, 'releaseYear': {'year': 2022, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 28, 'month': 3, 'year': 2022, '__typename': 'ReleaseDate'}, 'genre': 'Action'}, {'_id': '61e5db34909c2ca781570a73', 'id' ...
# The API call gave us a response of type: 200
#
#  ITERACION Action 35
#
#
# The answer for movies is type: <class 'dict'>, the length is: 4 and the keys are: dict_keys(['page', 'next', 'entries', 'results'])
#
# {'page': '35', 'next': '/titles?titleType=movie&genre=Action&page=36&limit=50&startYear=2010&endYear=2024', 'entries': 50, 'results': [{'_id': '620521ef38c4593d4a5bbacd', 'id': 'tt18076798', 'primaryImage': {'id': 'rm2808342273', 'width': 1818, 'height': 1912, 'url': 'https://m.media-amazon.com/images/M/MV5BNTcwYzY3ZTktOWYyYy00YTlkLTg5MGUtYjBmNGY3ODc4NzQxXkEyXkFqcGdeQXVyNzc5NDg5Mjc@._V1_.jpg', 'caption': {'plainText': 'Bloodhound (2022)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, 'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}], 'canHaveEpisodes': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Bloodhound', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Bloodhound', '__typename': 'TitleText'}, 'releaseYear': {'year': 2022, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 18, 'month': 2, 'year': 2022, '__typename': 'ReleaseDate'}, 'genre': 'Action'}, {'_id': '6207c5288236d9c2c4dfb384', 'id': 'tt18161070', 'primaryImage': {'id': 'rm2722031361', 'width': 530, 'height': 661, 'url': 'https://m.media-amazon.com/images/M/MV5BZmJhZDE0ZTgtNjdmNy00NDA5LWJiMjAtMTBiYWE2M2IxMTYwXkEyXkFqcGdeQXVyMTc2NzgzODM@._V1_.jpg', 'caption': {'plainText': 'Socorro: Beyond the Stars (2022)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Socorro: Beyond the Stars', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Socorro: Beyond the Stars', '__typename': 'TitleText'}, 'releaseYear': {'year': 2022, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': None, 'month': None, 'year': None, '__typename': 'ReleaseDate'}, 'genre': 'Action'}, {'_id': '6207c529a3b91bc473dfb372', 'id': 'tt18161114', 'primaryImage': {'id': 'rm4178437889', 'width': 1448, 'height': 2048, 'url': 'https://m.media-amazon.com/images/M/MV5BNDBjZDY0MjMtZDA3Yi00MDljLTlhMTQtZWVkMDIzMTM5YWVlXkEyXkFqcGdeQXVyNDgwNjI3MDk@._V1_.jpg', 'caption': {'plainText': 'Moez (2022)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, 'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}], 'canHaveEpisodes': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Moez', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Moez', '__typename': 'TitleText'}, 'releaseYear': {'year': 2022, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 9, 'month': 2, 'year': 2022, '__typename': 'ReleaseDate'}, 'genre': 'Action'}, {'_id': '620961245958d9e38a88e5d3', 'id': 'tt18183648', 'primaryImage': {'id': 'rm2080039937', 'width': 448, 'height': 640, 'url': 'https://m.media-amazon.com/images/M/MV5BNjIyNjFmNmYtOTBhNi00NTY4LTljMzMtZmY1MjFhYmFjMTBmXkEyXkFqcGdeQXVyOTUyODE0NDI@._V1_.jpg', 'caption': {'plainText': 'Daniel Hendler, Rodrigo Noya, Alan Sabbagh, Esteban Lamothe, Violeta Urtizberea, Esteban Bigliardi, Nico García, and Gastón Cocchiarale in El sistema K.E.OP/S (2022)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, 'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}], 'canHaveEpisodes': False, '__typename': 'TitleType'}, 'titleText': {'text': 'El sistema K.E.OP/S', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'El sistema K.E.OP/S', '__typename': 'TitleText'}, 'releaseYear': {'year': 2022, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 12, 'month': 5, 'year': 2022, '__typename': 'ReleaseDate'}, 'genre': 'Action'}, {'_id': '620961265958d9e38a88e5df', 'id': 'tt18183576', 'primaryImage': {'id': 'rm904061953', 'width': 1920, 'height': 1080, 'url': 'https://m.media-amazon.com/images/M/MV5BOTU3ZTEwM2QtZjNlMy00YWU5LWJjMmItZWVjZTU1MTBhZTEwXkEyXkFqcGdeQXVy ...
# The API call gave us a response of type: 200
#
#  ITERACION Action 36
#
#
# The answer for movies is type: <class 'dict'>, the length is: 4 and the keys are: dict_keys(['page', 'next', 'entries', 'results'])
#
# {'page': '36', 'next': '/titles?titleType=movie&genre=Action&page=37&limit=50&startYear=2010&endYear=2024', 'entries': 50, 'results': [{'_id': '6221166e0d075794d448796c', 'id': 'tt18363828', 'primaryImage': None, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, 'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}], 'canHaveEpisodes': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Bayern München gegen SpVgg Greuther Fürth', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Bayern München gegen SpVgg Greuther Fürth', '__typename': 'TitleText'}, 'releaseYear': {'year': 2022, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 20, 'month': 2, 'year': 2022, '__typename': 'ReleaseDate'}, 'genre': 'Action'}, {'_id': '62238291cf591e110469a842', 'id': 'tt18380542', 'primaryImage': {'id': 'rm2081491713', 'width': 1333, 'height': 2000, 'url': 'https://m.media-amazon.com/images/M/MV5BN2Q2YmQwNWEtOWMzMS00NjU4LWEyOTctMzlhN2Q3MDgyODI4XkEyXkFqcGdeQXVyODYxODQyMjU@._V1_.jpg', 'caption': {'plainText': 'Zhong Kui Exorcism (2022)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, 'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}], 'canHaveEpisodes': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Zhong Kui Exorcism', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Zhong Kui Exorcism', '__typename': 'TitleText'}, 'releaseYear': {'year': 2022, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 22, 'month': 1, 'year': 2022, '__typename': 'ReleaseDate'}, 'genre': 'Action'}, {'_id': '622382e6da5324cee369aa26', 'id': 'tt18394986', 'primaryImage': {'id': 'rm3506510593', 'width': 820, 'height': 1408, 'url': 'https://m.media-amazon.com/images/M/MV5BMjBlZmEwNTYtZGQ1NC00OWJjLWJkMjMtN2JkNzZiOTc5MDJjXkEyXkFqcGdeQXVyMTQ4ODg3MDM2._V1_.jpg', 'caption': {'plainText': 'Mr. Franklin (2022)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, 'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}], 'canHaveEpisodes': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Mr. Franklin', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Mr. Franklin', '__typename': 'TitleText'}, 'releaseYear': {'year': 2022, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': None, 'month': None, 'year': 2022, '__typename': 'ReleaseDate'}, 'genre': 'Action'}, {'_id': '6224d3db4d2a306f183249a0', 'id': 'tt18413076', 'primaryImage': None, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Mr. Franklin', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Mr. Franklin', '__typename': 'TitleText'}, 'releaseYear': {'year': 2022, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': None, 'month': None, 'year': 2022, '__typename': 'ReleaseDate'}, 'genre': 'Action'}, {'_id': '6224d4444d2a306f18324bde', 'id': 'tt18454132', 'primaryImage': {'id': 'rm2251037185', 'width': 822, 'height': 1188, 'url': 'https://m.media-amazon.com/images/M/MV5BYjJhM2MyZDItOWNmMS00YzhmLWE3ZjQtNzIyYTg3YTNjZWEzXkEyXkFqcGdeQXVyMjc0Nzk1Mg@@._V1_.jpg', 'caption': {'plainText': 'Amityville in Space (2022)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, 'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}], 'canHaveEpisodes': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Amityville in Space', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Amityville in Space', '__typename': 'TitleText'}, 'releaseYear': {'year': 2022, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 19, 'month': 7, 'year': 2022, '__typename': 'ReleaseDate'} ...
# The API call gave us a response of type: 200
#
#  ITERACION Action 37
#
#
# The answer for movies is type: <class 'dict'>, the length is: 4 and the keys are: dict_keys(['page', 'next', 'entries', 'results'])
#
# {'page': '37', 'next': '/titles?titleType=movie&genre=Action&page=38&limit=50&startYear=2010&endYear=2024', 'entries': 50, 'results': [{'_id': '624bfe1609022e1a9167548f', 'id': 'tt19369380', 'primaryImage': None, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, 'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}], 'canHaveEpisodes': False, '__typename': 'TitleType'}, 'titleText': {'text': "Dawn's Early Light", '__typename': 'TitleText'}, 'originalTitleText': {'text': "Dawn's Early Light", '__typename': 'TitleText'}, 'releaseYear': {'year': 2022, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 3, 'month': 3, 'year': 2022, '__typename': 'ReleaseDate'}, 'genre': 'Action'}, {'_id': '624d4faeafadbda0f1765bc7', 'id': 'tt19372510', 'primaryImage': None, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, 'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}], 'canHaveEpisodes': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Gangstar Munna', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Gangstar Munna', '__typename': 'TitleText'}, 'releaseYear': {'year': 2022, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 3, 'month': 2, 'year': 2022, '__typename': 'ReleaseDate'}, 'genre': 'Action'}, {'_id': '624d4fe585a6a31a86765d15', 'id': 'tt19379402', 'primaryImage': {'id': 'rm2339118593', 'width': 1543, 'height': 1930, 'url': 'https://m.media-amazon.com/images/M/MV5BMjJlMjhlOWYtMDM0Yy00MDIzLTk1ZTEtNGUyMjY3NDJkMjJlXkEyXkFqcGdeQXVyMTUxNzA5MDYx._V1_.jpg', 'caption': {'plainText': 'Tejas Kolekar in Tejas Kolekar (2022)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, 'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}], 'canHaveEpisodes': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Tejas Kolekar', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Tejas Kolekar', '__typename': 'TitleText'}, 'releaseYear': {'year': 2022, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 15, 'month': 4, 'year': 2022, '__typename': 'ReleaseDate'}, 'genre': 'Action'}, {'_id': '625143cf7a8be37bd922e74e', 'id': 'tt19396532', 'primaryImage': {'id': 'rm2673286657', 'width': 4134, 'height': 5906, 'url': 'https://m.media-amazon.com/images/M/MV5BOTJmYmM2OGYtZjc4MS00ODU2LWFmNWQtNDNiNGRiZWY2YzZlXkEyXkFqcGdeQXVyODkyNzE0Mjg@._V1_.jpg', 'caption': {'plainText': 'Las Guerras del Narcotráfico El retorno de LJ (2022)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, 'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}], 'canHaveEpisodes': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Las Guerras del Narcotráfico El retorno de LJ', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Las Guerras del Narcotráfico El retorno de LJ', '__typename': 'TitleText'}, 'releaseYear': {'year': 2022, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 26, 'month': 3, 'year': 2022, '__typename': 'ReleaseDate'}, 'genre': 'Action'}, {'_id': '625143d97a8be37bd922e794', 'id': 'tt19397296', 'primaryImage': {'id': 'rm2841059073', 'width': 936, 'height': 1322, 'url': 'https://m.media-amazon.com/images/M/MV5BOTkzOGEyMGQtMGMxZi00Y2NlLWIzNjctODhiZWE0YjQxNjc4XkEyXkFqcGdeQXVyMjIxMzMyMQ@@._V1_.jpg', 'caption': {'plainText': 'Tri Tygri ve filmu: Jackpot (2022)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, 'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}], 'canHaveEpisodes': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Tri Tygri ve filmu: Jackpot', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Tri Tygri ve filmu: Jackpot', '__typename': ' ...
# The API call gave us a response of type: 200
#
#  ITERACION Action 38
#
#
# The answer for movies is type: <class 'dict'>, the length is: 4 and the keys are: dict_keys(['page', 'next', 'entries', 'results'])
#
# {'page': '38', 'next': '/titles?titleType=movie&genre=Action&page=39&limit=50&startYear=2010&endYear=2024', 'entries': 50, 'results': [{'_id': '6270e82581e48a501430e852', 'id': 'tt19878422', 'primaryImage': {'id': 'rm1550124801', 'width': 2240, 'height': 3200, 'url': 'https://m.media-amazon.com/images/M/MV5BYWQzODgxOGItOWNhNy00MWI0LWJmNWQtOTdmNWEyYTMyMGE2XkEyXkFqcGdeQXVyNzY0MDAwNzc@._V1_.jpg', 'caption': {'plainText': 'Daniyar Alshinov in Vremya patriotov (2022)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, 'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}], 'canHaveEpisodes': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Vremya patriotov', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Vremya patriotov', '__typename': 'TitleText'}, 'releaseYear': {'year': 2022, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 28, 'month': 4, 'year': 2022, '__typename': 'ReleaseDate'}, 'genre': 'Action'}, {'_id': '6270e859a2e08899d130e988', 'id': 'tt19881248', 'primaryImage': {'id': 'rm2677674497', 'width': 1617, 'height': 2279, 'url': 'https://m.media-amazon.com/images/M/MV5BZmM1ZDQ4NjMtYzIzMC00MTM5LWFkZjktYWEyMmMyOThlNzYxXkEyXkFqcGdeQXVyMTA2MTc1OTUw._V1_.jpg', 'caption': {'plainText': 'Oscar Byrne, Freddie Potts, Tom Chapman-fox, and Jack Helm in Oslacraft: the movie (2022)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, 'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}], 'canHaveEpisodes': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Oslacraft: the movie', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Oslacraft: the movie', '__typename': 'TitleText'}, 'releaseYear': {'year': 2022, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 6, 'month': 1, 'year': 2022, '__typename': 'ReleaseDate'}, 'genre': 'Action'}, {'_id': '6272397d8bf327e15737de6a', 'id': 'tt19881358', 'primaryImage': None, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, 'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}], 'canHaveEpisodes': False, '__typename': 'TitleType'}, 'titleText': {'text': "Blake's Movie 2: Pizza Mayhem", '__typename': 'TitleText'}, 'originalTitleText': {'text': "Blake's Movie 2: Pizza Mayhem", '__typename': 'TitleText'}, 'releaseYear': {'year': 2022, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 30, 'month': 4, 'year': 2022, '__typename': 'ReleaseDate'}, 'genre': 'Action'}, {'_id': '627239ada45152513c37dfba', 'id': 'tt19885346', 'primaryImage': {'id': 'rm4247654913', 'width': 1280, 'height': 640, 'url': 'https://m.media-amazon.com/images/M/MV5BYmNkMzY0ZjYtYWFjNy00YTEyLWJiYWQtYjMwMzkxNGIyNDExXkEyXkFqcGdeQXVyMTM1NzQ1ODI1._V1_.jpg', 'caption': {'plainText': 'Shree Kumar Pandey, Priyanka Maharaj, Ravi Shankar Mishra, Umesh Singh, Roshani Singh, and Anjana Singh in Hum Suryavasham Hain (2022)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, 'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}], 'canHaveEpisodes': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Hum Suryavasham Hain', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Hum Suryavasham Hain', '__typename': 'TitleText'}, 'releaseYear': {'year': 2022, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 17, 'month': 6, 'year': 2022, '__typename': 'ReleaseDate'}, 'genre': 'Action'}, {'_id': '627239bca45152513c37e02c', 'id': 'tt19886644', 'primaryImage': {'id': 'rm4178648321', 'width': 760, 'height': 425, 'url': 'https://m.media-amazon.com/images/M/MV5BODdiNzI3ZmYtNDhlNC00NjYyLWEzMmUtMGZmN2RhNTk4ODcxXkEyXkFqcGdeQXVyMTEyMDI0ODYz._V1_.jpg', 'caption': {'plainText': 'Spider Man: Hunted (2022) ...
# The API call gave us a response of type: 200
#
#  ITERACION Action 39
#
#
# The answer for movies is type: <class 'dict'>, the length is: 4 and the keys are: dict_keys(['page', 'next', 'entries', 'results'])
#
# {'page': '39', 'next': '/titles?titleType=movie&genre=Action&page=40&limit=50&startYear=2010&endYear=2024', 'entries': 50, 'results': [{'_id': '6291dd84aaec0c6ea5492d55', 'id': 'tt20583296', 'primaryImage': {'id': 'rm3287420161', 'width': 2480, 'height': 3508, 'url': 'https://m.media-amazon.com/images/M/MV5BYTE1MjlhYzktMGYyZi00YzU5LWJjNjAtYmE1NjRmZmI4ODU3XkEyXkFqcGdeQXVyOTk4MDY3OTc@._V1_.jpg', 'caption': {'plainText': 'Lady Trillion (2022)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, 'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}], 'canHaveEpisodes': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Lady Trillion', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Lady Trillion', '__typename': 'TitleText'}, 'releaseYear': {'year': 2022, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 13, 'month': 9, 'year': 2022, '__typename': 'ReleaseDate'}, 'genre': 'Action'}, {'_id': '6294808f33fda580693849de', 'id': 'tt20673318', 'primaryImage': {'id': 'rm533205249', 'width': 1118, 'height': 1583, 'url': 'https://m.media-amazon.com/images/M/MV5BMmU4N2EzMmQtZjJkYi00YTQzLTkwMGEtNTk0Y2VkODQ5ZmVjXkEyXkFqcGdeQXVyMTQ5NzgyNDg5._V1_.jpg', 'caption': {'plainText': 'The Bigger Picture (2022)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, 'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}], 'canHaveEpisodes': False, '__typename': 'TitleType'}, 'titleText': {'text': 'The Bigger Picture', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'The Bigger Picture', '__typename': 'TitleText'}, 'releaseYear': {'year': 2022, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': None, 'month': None, 'year': 2022, '__typename': 'ReleaseDate'}, 'genre': 'Action'}, {'_id': '6295d2268d8b7980ae248134', 'id': 'tt20726444', 'primaryImage': {'id': 'rm1605439745', 'width': 396, 'height': 594, 'url': 'https://m.media-amazon.com/images/M/MV5BZGNmZjhiMjAtN2M5Yy00NmM3LTlhNWMtMWQ0NDFkMjUxYjUxXkEyXkFqcGdeQXVyNTQ4NzY3NA@@._V1_.jpg', 'caption': {'plainText': 'Top Gunner: Danger Zone (2022)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, 'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}], 'canHaveEpisodes': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Top Gunner: Danger Zone', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Top Gunner: Danger Zone', '__typename': 'TitleText'}, 'releaseYear': {'year': 2022, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 20, 'month': 5, 'year': 2022, '__typename': 'ReleaseDate'}, 'genre': 'Action'}, {'_id': '6295d25d9e4928b4df248262', 'id': 'tt20752126', 'primaryImage': {'id': 'rm2443972865', 'width': 1080, 'height': 1578, 'url': 'https://m.media-amazon.com/images/M/MV5BMjA1ZDZhZWMtYzBhOC00MjJlLWEyYmEtYjgwZmIwYTgyYzIzXkEyXkFqcGdeQXVyMjQwMjk0NjI@._V1_.jpg', 'caption': {'plainText': 'Breakout Brothers 3 (2022)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, 'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}], 'canHaveEpisodes': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Breakout Brothers 3', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'To yuk hing dai 3', '__typename': 'TitleText'}, 'releaseYear': {'year': 2022, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 28, 'month': 5, 'year': 2022, '__typename': 'ReleaseDate'}, 'genre': 'Action'}, {'_id': '6297237d7e272e5c06b5bf4c', 'id': 'tt20724796', 'primaryImage': {'id': 'rm2378043649', 'width': 2000, 'height': 3000, 'url': 'https://m.media-amazon.com/images/M/MV5BNGRlODk2NTctNmRjNS00YjhmLTllYzAtMmJhNDY1NjIwOTA5XkEyXkFqcGde ...
# The API call gave us a response of type: 200
#
#  ITERACION Action 40
#
#
# The answer for movies is type: <class 'dict'>, the length is: 4 and the keys are: dict_keys(['page', 'next', 'entries', 'results'])
#
# {'page': '40', 'next': '/titles?titleType=movie&genre=Action&page=41&limit=50&startYear=2010&endYear=2024', 'entries': 50, 'results': [{'_id': '62babc651aa53737864cc5e6', 'id': 'tt21141802', 'primaryImage': {'id': 'rm3092452353', 'width': 4429, 'height': 7382, 'url': 'https://m.media-amazon.com/images/M/MV5BNDhkMmQ5ODktZjcxNy00ZjljLWEyMTYtMzAyMTcyYzBlZTZkXkEyXkFqcGdeQXVyODk3OTU3NDk@._V1_.jpg', 'caption': {'plainText': 'Marshall Mu GuiYing (2022)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, 'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}], 'canHaveEpisodes': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Marshall Mu GuiYing', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Marshall Mu GuiYing', '__typename': 'TitleText'}, 'releaseYear': {'year': 2022, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 1, 'month': 1, 'year': 2022, '__typename': 'ReleaseDate'}, 'genre': 'Action'}, {'_id': '62babc682d196230454cc5f2', 'id': 'tt21141856', 'primaryImage': {'id': 'rm337384449', 'width': 770, 'height': 1080, 'url': 'https://m.media-amazon.com/images/M/MV5BYzVkNTczMzUtY2U3OC00NThjLWE3OTEtOTM3YTY5ZWYxM2ZhXkEyXkFqcGdeQXVyODk3OTU3NDk@._V1_.jpg', 'caption': {'plainText': 'KunLun Battle (2022)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, 'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}], 'canHaveEpisodes': False, '__typename': 'TitleType'}, 'titleText': {'text': 'KunLun Battle', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'KunLun Battle', '__typename': 'TitleText'}, 'releaseYear': {'year': 2022, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 14, 'month': 2, 'year': 2022, '__typename': 'ReleaseDate'}, 'genre': 'Action'}, {'_id': '62bc0df3f5616366475d0977', 'id': 'tt21146674', 'primaryImage': {'id': 'rm1335755777', 'width': 456, 'height': 646, 'url': 'https://m.media-amazon.com/images/M/MV5BZTRmZTQxMjktMzU0MC00OWZjLTllZDctN2NlYzIxMmNkMDAyXkEyXkFqcGdeQXVyODU4Nzg1MjY@._V1_.jpg', 'caption': {'plainText': 'Snake 3 (2022)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, 'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}], 'canHaveEpisodes': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Snake 3', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Snake 3', '__typename': 'TitleText'}, 'releaseYear': {'year': 2022, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 22, 'month': 1, 'year': 2022, '__typename': 'ReleaseDate'}, 'genre': 'Action'}, {'_id': '62bd5f9d59370411c81a9926', 'id': 'tt21154238', 'primaryImage': None, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, 'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}], 'canHaveEpisodes': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Young Heroes of Chaotic Time', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Young Heroes of Chaotic Time', '__typename': 'TitleText'}, 'releaseYear': {'year': 2022, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 15, 'month': 7, 'year': 2022, '__typename': 'ReleaseDate'}, 'genre': 'Action'}, {'_id': '62bd5fa74b083e419b1a995e', 'id': 'tt21154882', 'primaryImage': {'id': 'rm232330497', 'width': 3600, 'height': 2400, 'url': 'https://m.media-amazon.com/images/M/MV5BMGI1NTFiZTItYjBmNS00NDg1LTllNjItYzkxNGQ5MjM4N2IzXkEyXkFqcGdeQXVyMTA4MzQ4NzMw._V1_.jpg', 'caption': {'plainText': 'Foreign Sarakku (2022)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, 'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}], 'canHaveEpisodes': False, '__typename ...
# The API call gave us a response of type: 200
#
#  ITERACION Action 41
#
#
# The answer for movies is type: <class 'dict'>, the length is: 4 and the keys are: dict_keys(['page', 'next', 'entries', 'results'])
#
# {'page': '41', 'next': '/titles?titleType=movie&genre=Action&page=42&limit=50&startYear=2010&endYear=2024', 'entries': 50, 'results': [{'_id': '62e39b6dcc399ccd3046a75f', 'id': 'tt21377168', 'primaryImage': {'id': 'rm1867253761', 'width': 900, 'height': 1285, 'url': 'https://m.media-amazon.com/images/M/MV5BNjM0MmVjMmYtNzM1Ni00MmE3LWFmZTgtODZjN2UyMDNiMmNiXkEyXkFqcGdeQXVyMTM3MTMxODk0._V1_.jpg', 'caption': {'plainText': 'Gary Crenshaw and Denzell Dandridge in Bond Money (2022)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, 'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}], 'canHaveEpisodes': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Bond Money', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Bond Money', '__typename': 'TitleText'}, 'releaseYear': {'year': 2022, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 4, 'month': 6, 'year': 2022, '__typename': 'ReleaseDate'}, 'genre': 'Action'}, {'_id': '62e39b8525be754e2f46a7f1', 'id': 'tt21379370', 'primaryImage': {'id': 'rm3091400705', 'width': 2000, 'height': 3000, 'url': 'https://m.media-amazon.com/images/M/MV5BOTk3NmJkMTUtOGE4NS00YmIxLTkyNDAtZTU2MzUyMzRlYTFhXkEyXkFqcGdeQXVyMTUwNzQzNzUz._V1_.jpg', 'caption': {'plainText': 'Rechipodam Brother (2022)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, 'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}], 'canHaveEpisodes': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Rechipodam Brother', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Rechipodam Brother', '__typename': 'TitleText'}, 'releaseYear': {'year': 2022, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 29, 'month': 7, 'year': 2022, '__typename': 'ReleaseDate'}, 'genre': 'Action'}, {'_id': '62e4ec5223af336cd69371f1', 'id': 'tt21387514', 'primaryImage': {'id': 'rm2171341825', 'width': 470, 'height': 700, 'url': 'https://m.media-amazon.com/images/M/MV5BYzM0Yzk4NGItM2Q3Yi00MDk0LThiYzgtN2ExNWM4MmU3NTY2XkEyXkFqcGdeQXVyNTM0NTU5Mg@@._V1_.jpg', 'caption': {'plainText': 'Bohoja (2022)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, 'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}], 'canHaveEpisodes': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Bohoja', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Bohoja', '__typename': 'TitleText'}, 'releaseYear': {'year': 2022, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': None, 'month': None, 'year': 2023, '__typename': 'ReleaseDate'}, 'genre': 'Action'}, {'_id': '62e78f995ae016ccd4cd09f1', 'id': 'tt21405534', 'primaryImage': {'id': 'rm737085697', 'width': 1728, 'height': 2592, 'url': 'https://m.media-amazon.com/images/M/MV5BZjAzNjg3NzctNGVmZS00ZTFmLThlNDYtZDRkN2QxZWQ1ZGUxXkEyXkFqcGdeQXVyMjU4Mzk3NzM@._V1_.jpg', 'caption': {'plainText': 'Paulina Dmytrenko, Karmel Bortoleti, and Gordon Scott Venters in Retribution: Venganza (2022)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, 'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}], 'canHaveEpisodes': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Retribution: Venganza', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Retribution: Venganza', '__typename': 'TitleText'}, 'releaseYear': {'year': 2022, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 23, 'month': 7, 'year': 2022, '__typename': 'ReleaseDate'}, 'genre': 'Action'}, {'_id': '62e8e0dc64de3f6cfc25136a', 'id': 'tt21411734', 'primaryImage': {'id': 'rm2617116929', 'width': 1182, 'height': 1572, 'url': 'https://m.media-amazon.com/images/M/MV5BYWFkNGZmMD ...
# The API call gave us a response of type: 200
#
#  ITERACION Action 42
#
#
# The answer for movies is type: <class 'dict'>, the length is: 4 and the keys are: dict_keys(['page', 'next', 'entries', 'results'])
#
# ...
# The API call gave us a response of type: 200
#
#  ITERACION Action 58
#
#
# The answer for shorts is type: <class 'dict'>, the length is: 4 and the keys are: dict_keys(['page', 'next', 'entries', 'results'])
#
# {'page': 1, 'next': '/titles?titleType=short&genre=Action&page=2&limit=50&startYear=2010&endYear=2024', 'entries': 50, 'results': [{'_id': '61e59c5dd735dff3f947d1d1', 'id': 'tt12925840', 'primaryImage': {'id': 'rm835756801', 'width': 1673, 'height': 2145, 'url': 'https://m.media-amazon.com/images/M/MV5BMjE5ZDU0ZWMtYWE4NS00MWVkLWEwN2EtYTFhMWRhNWExYWI5XkEyXkFqcGdeQXVyODIxMDcyMjk@._V1_.jpg', 'caption': {'plainText': 'Eddie Thurber-IV-Victor the Shovel Returns (2024)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Short', 'id': 'short', 'isSeries': False, 'isEpisode': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Eddie Thurber-IV-Victor the Shovel Returns', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Eddie Thurber-IV-Victor the Shovel Returns', '__typename': 'TitleText'}, 'releaseYear': {'year': 2024, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 1, 'month': 7, 'year': 2024, '__typename': 'ReleaseDate'}, 'genre': 'Action'}, {'_id': '622116b6e61085d889487a65', 'id': 'tt18376030', 'primaryImage': None, 'titleType': {'displayableProperty': {'value': {'plainText': 'Short', '__typename': 'Markdown'}, '__typename': 'DisplayableTitleTypeProperty'}, 'text': 'Short', 'id': 'short', 'isSeries': False, 'isEpisode': False, 'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}], 'canHaveEpisodes': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Chromakill', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Chromakill', '__typename': 'TitleText'}, 'releaseYear': {'year': 2024, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': None, 'month': None, 'year': 2024, '__typename': 'ReleaseDate'}, 'genre': 'Action'}, {'_id': '625d215807f2fad917318eda', 'id': 'tt19714242', 'primaryImage': {'id': 'rm2010725889', 'width': 4050, 'height': 6000, 'url': 'https://m.media-amazon.com/images/M/MV5BY2YwZDY2ODctZTI1MS00YTE0LWFiNTYtYTc0YWYwYWFmZTViXkEyXkFqcGdeQXVyOTY1ODI1Mjc@._V1_.jpg', 'caption': {'plainText': 'SI-BO (2024)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'displayableProperty': {'value': {'plainText': 'Short', '__typename': 'Markdown'}, '__typename': 'DisplayableTitleTypeProperty'}, 'text': 'Short', 'id': 'short', 'isSeries': False, 'isEpisode': False, 'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}], 'canHaveEpisodes': False, '__typename': 'TitleType'}, 'titleText': {'text': 'SI-BO', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'SI-BO', '__typename': 'TitleText'}, 'releaseYear': {'year': 2024, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': None, 'month': None, 'year': 2024, '__typename': 'ReleaseDate'}, 'genre': 'Action'}, {'_id': '6311bffc659dae1c6206beea', 'id': 'tt21937488', 'primaryImage': None, 'titleType': {'text': 'Short', 'id': 'short', 'isSeries': False, 'isEpisode': False, 'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}], 'canHaveEpisodes': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Wastelander Part 2', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Wastelander Part 2', '__typename': 'TitleText'}, 'releaseYear': {'year': 2024, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 25, 'month': 9, 'year': 2024, '__typename': 'ReleaseDate'}, 'genre': 'Action'}, {'_id': '63b5ca32959eac2f403e4597', 'id': 'tt25424920', 'primaryImage': {'id': 'rm3146732033', 'width': 700, 'height': 394, 'url': 'https://m.media-amazon.com/images/M/MV5BNTkxMTc3MTAtNzc4NC00ZDE1LWJkOTUtMTg5ODA0MmM2M2I0XkEyXkFqcGdeQXVyOTM3NzY0Nw@@._V1_.jpg', 'caption': {'plainText': 'Danaë Grieef, Elijah Ormesher, Stephanie Ristrom, Jax Joy, Daniel Doutch, Emma Spencer, Alex Iozzi, Tom Pham, Natalie Rowe, Nicole Chapman, Scott David Lister, Cayde Joy, and Aaron McDougall in Loaded Deliberation (2024)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'displayableProperty': {'value': {'plainText': 'Short', ' ...
# The API call gave us a response of type: 200
#
#  ITERACION Action 59
#
#
# The answer for shorts is type: <class 'dict'>, the length is: 4 and the keys are: dict_keys(['page', 'next', 'entries', 'results'])
#
# {'page': 1, 'next': '/titles?titleType=short&genre=Action&page=2&limit=50&startYear=2010&endYear=2024', 'entries': 50, 'results': [{'_id': '61e59c5dd735dff3f947d1d1', 'id': 'tt12925840', 'primaryImage': {'id': 'rm835756801', 'width': 1673, 'height': 2145, 'url': 'https://m.media-amazon.com/images/M/MV5BMjE5ZDU0ZWMtYWE4NS00MWVkLWEwN2EtYTFhMWRhNWExYWI5XkEyXkFqcGdeQXVyODIxMDcyMjk@._V1_.jpg', 'caption': {'plainText': 'Eddie Thurber-IV-Victor the Shovel Returns (2024)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Short', 'id': 'short', 'isSeries': False, 'isEpisode': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Eddie Thurber-IV-Victor the Shovel Returns', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Eddie Thurber-IV-Victor the Shovel Returns', '__typename': 'TitleText'}, 'releaseYear': {'year': 2024, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 1, 'month': 7, 'year': 2024, '__typename': 'ReleaseDate'}, 'genre': 'Action'}, {'_id': '622116b6e61085d889487a65', 'id': 'tt18376030', 'primaryImage': None, 'titleType': {'displayableProperty': {'value': {'plainText': 'Short', '__typename': 'Markdown'}, '__typename': 'DisplayableTitleTypeProperty'}, 'text': 'Short', 'id': 'short', 'isSeries': False, 'isEpisode': False, 'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}], 'canHaveEpisodes': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Chromakill', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Chromakill', '__typename': 'TitleText'}, 'releaseYear': {'year': 2024, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': None, 'month': None, 'year': 2024, '__typename': 'ReleaseDate'}, 'genre': 'Action'}, {'_id': '625d215807f2fad917318eda', 'id': 'tt19714242', 'primaryImage': {'id': 'rm2010725889', 'width': 4050, 'height': 6000, 'url': 'https://m.media-amazon.com/images/M/MV5BY2YwZDY2ODctZTI1MS00YTE0LWFiNTYtYTc0YWYwYWFmZTViXkEyXkFqcGdeQXVyOTY1ODI1Mjc@._V1_.jpg', 'caption': {'plainText': 'SI-BO (2024)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'displayableProperty': {'value': {'plainText': 'Short', '__typename': 'Markdown'}, '__typename': 'DisplayableTitleTypeProperty'}, 'text': 'Short', 'id': 'short', 'isSeries': False, 'isEpisode': False, 'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}], 'canHaveEpisodes': False, '__typename': 'TitleType'}, 'titleText': {'text': 'SI-BO', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'SI-BO', '__typename': 'TitleText'}, 'releaseYear': {'year': 2024, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': None, 'month': None, 'year': 2024, '__typename': 'ReleaseDate'}, 'genre': 'Action'}, {'_id': '6311bffc659dae1c6206beea', 'id': 'tt21937488', 'primaryImage': None, 'titleType': {'text': 'Short', 'id': 'short', 'isSeries': False, 'isEpisode': False, 'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}], 'canHaveEpisodes': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Wastelander Part 2', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Wastelander Part 2', '__typename': 'TitleText'}, 'releaseYear': {'year': 2024, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 25, 'month': 9, 'year': 2024, '__typename': 'ReleaseDate'}, 'genre': 'Action'}, {'_id': '63b5ca32959eac2f403e4597', 'id': 'tt25424920', 'primaryImage': {'id': 'rm3146732033', 'width': 700, 'height': 394, 'url': 'https://m.media-amazon.com/images/M/MV5BNTkxMTc3MTAtNzc4NC00ZDE1LWJkOTUtMTg5ODA0MmM2M2I0XkEyXkFqcGdeQXVyOTM3NzY0Nw@@._V1_.jpg', 'caption': {'plainText': 'Danaë Grieef, Elijah Ormesher, Stephanie Ristrom, Jax Joy, Daniel Doutch, Emma Spencer, Alex Iozzi, Tom Pham, Natalie Rowe, Nicole Chapman, Scott David Lister, Cayde Joy, and Aaron McDougall in Loaded Deliberation (2024)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'displayableProperty': {'value': {'plainText': 'Short', ' ...
# The API call gave us a response of type: 200
#
#  ITERACION Action 60
#
#
# The answer for shorts is type: <class 'dict'>, the length is: 4 and the keys are: dict_keys(['page', 'next', 'entries', 'results'])
#
# {'page': 1, 'next': '/titles?titleType=short&genre=Action&page=2&limit=50&startYear=2010&endYear=2024', 'entries': 50, 'results': [{'_id': '61e59c5dd735dff3f947d1d1', 'id': 'tt12925840', 'primaryImage': {'id': 'rm835756801', 'width': 1673, 'height': 2145, 'url': 'https://m.media-amazon.com/images/M/MV5BMjE5ZDU0ZWMtYWE4NS00MWVkLWEwN2EtYTFhMWRhNWExYWI5XkEyXkFqcGdeQXVyODIxMDcyMjk@._V1_.jpg', 'caption': {'plainText': 'Eddie Thurber-IV-Victor the Shovel Returns (2024)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Short', 'id': 'short', 'isSeries': False, 'isEpisode': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Eddie Thurber-IV-Victor the Shovel Returns', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Eddie Thurber-IV-Victor the Shovel Returns', '__typename': 'TitleText'}, 'releaseYear': {'year': 2024, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 1, 'month': 7, 'year': 2024, '__typename': 'ReleaseDate'}, 'genre': 'Action'}, {'_id': '622116b6e61085d889487a65', 'id': 'tt18376030', 'primaryImage': None, 'titleType': {'displayableProperty': {'value': {'plainText': 'Short', '__typename': 'Markdown'}, '__typename': 'DisplayableTitleTypeProperty'}, 'text': 'Short', 'id': 'short', 'isSeries': False, 'isEpisode': False, 'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}], 'canHaveEpisodes': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Chromakill', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Chromakill', '__typename': 'TitleText'}, 'releaseYear': {'year': 2024, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': None, 'month': None, 'year': 2024, '__typename': 'ReleaseDate'}, 'genre': 'Action'}, {'_id': '625d215807f2fad917318eda', 'id': 'tt19714242', 'primaryImage': {'id': 'rm2010725889', 'width': 4050, 'height': 6000, 'url': 'https://m.media-amazon.com/images/M/MV5BY2YwZDY2ODctZTI1MS00YTE0LWFiNTYtYTc0YWYwYWFmZTViXkEyXkFqcGdeQXVyOTY1ODI1Mjc@._V1_.jpg', 'caption': {'plainText': 'SI-BO (2024)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'displayableProperty': {'value': {'plainText': 'Short', '__typename': 'Markdown'}, '__typename': 'DisplayableTitleTypeProperty'}, 'text': 'Short', 'id': 'short', 'isSeries': False, 'isEpisode': False, 'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}], 'canHaveEpisodes': False, '__typename': 'TitleType'}, 'titleText': {'text': 'SI-BO', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'SI-BO', '__typename': 'TitleText'}, 'releaseYear': {'year': 2024, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': None, 'month': None, 'year': 2024, '__typename': 'ReleaseDate'}, 'genre': 'Action'}, {'_id': '6311bffc659dae1c6206beea', 'id': 'tt21937488', 'primaryImage': None, 'titleType': {'text': 'Short', 'id': 'short', 'isSeries': False, 'isEpisode': False, 'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}], 'canHaveEpisodes': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Wastelander Part 2', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Wastelander Part 2', '__typename': 'TitleText'}, 'releaseYear': {'year': 2024, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 25, 'month': 9, 'year': 2024, '__typename': 'ReleaseDate'}, 'genre': 'Action'}, {'_id': '63b5ca32959eac2f403e4597', 'id': 'tt25424920', 'primaryImage': {'id': 'rm3146732033', 'width': 700, 'height': 394, 'url': 'https://m.media-amazon.com/images/M/MV5BNTkxMTc3MTAtNzc4NC00ZDE1LWJkOTUtMTg5ODA0MmM2M2I0XkEyXkFqcGdeQXVyOTM3NzY0Nw@@._V1_.jpg', 'caption': {'plainText': 'Danaë Grieef, Elijah Ormesher, Stephanie Ristrom, Jax Joy, Daniel Doutch, Emma Spencer, Alex Iozzi, Tom Pham, Natalie Rowe, Nicole Chapman, Scott David Lister, Cayde Joy, and Aaron McDougall in Loaded Deliberation (2024)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'displayableProperty': {'value': {'plainText': 'Short', ' ...
#              type                         name  release_year release_month  \
# id_imdb
# tt15708990  Movie                 Black Widows          2022            12
# tt1630029   Movie     Avatar: The Way of Water          2022            12
# tt1649418   Movie                 The Gray Man          2022             7
# tt1655444   Movie          There Are No Saints          2022             5
# tt1745960   Movie            Top Gun: Maverick          2022             5
# ...           ...                          ...           ...           ...
# tt30888126  Short  The Super Mario Super Movie          2024             1
# tt30923639  Short       Andy Crashes Christmas          2024            11
# tt30948133  Short                  Live Combat          2024             2
# tt30956555  Short                 The Proposal          2024             3
# tt30958748  Short                     The BYND          2024          None
#
#              genre
# id_imdb
# tt15708990  Action
# tt1630029   Action
# tt1649418   Action
# tt1655444   Action
# tt1745960   Action
# ...            ...
# tt30888126  Action
# tt30923639  Action
# tt30948133  Action
# tt30956555  Action
# tt30958748  Action
#
# [3000 rows x 5 columns]

# %%
# Save CSV
df_full_movie_list.to_csv("data/list_action_range_PRUEBA_API.csv")
